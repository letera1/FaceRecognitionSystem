# %% [markdown]
# # Modern Face Recognition Training
# ## Using Deep Learning (dlib + face_recognition)
#
# This notebook trains a state-of-the-art face recognition system using:
# - **dlib**: 68-point facial landmark detection
# - **face_recognition**: 128-dimensional face encodings
# - **SVM/KNN**: Classification on embeddings
# - **MTCNN**: Modern face detection (optional)

# %%
import sys
sys.path.append('..')

import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import face_recognition

from config import Config
from models.deep_face_model import DeepFaceModel, MTCNNFaceDetector
from utils import DataManager

Config.create_directories()

print("✅ Libraries imported successfully!")
print(f"Using face_recognition version: {face_recognition.__version__}")
